# %%
import numpy as np
import pandas as pd

nfl_v4=pd.read_csv('./NFL Play by Play 2009-2017 (v4).csv', index_col='Date')
# Out:
# /var/folders/8m/tdc0gjb14qq878phzzsj20l80000gn/T/ipykernel_47401/3282684392.py:4: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_v4=pd.read_csv('./NFL Play by Play 2009-2017 (v4).csv', index_col='Date')

# %%
nfl_v4.head()
# Out:
#                 GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# Date
# 2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#             PlayTimeDiff SideofField  yrdln  ...    yacEPA  Home_WP_pre  \
# Date                                         ...
# 2009-09-10           0.0         TEN   30.0  ...       NaN     0.485675
# 2009-09-10           7.0         PIT   42.0  ...  1.146076     0.546433
# 2009-09-10          37.0         PIT   47.0  ...       NaN     0.551088
# 2009-09-10          41.0         PIT   44.0  ... -5.031425     0.510793
# 2009-09-10           8.0         PIT   44.0  ...       NaN     0.461217
#
# ...

# %%
#Getting the number of missed values
missing_values_count = nfl_v4.isnull().sum()

# %%
print(missing_values_count)
# Out:
# GameID           0
# Drive            0
# qtr              0
# down         61154
# time           224
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 101, dtype: int64

# %%
#Get total percentage of missed values
nfl_v4.shape
total_cell_count = np.product(nfl_v4.shape)
total_missing_count = missing_values_count.sum()
total_percent_missing = (total_missing_count/total_cell_count)*100
print(total_percent_missing)
# Out:
# 25.118400092790814

# %% [markdown]
# ### Figure out why some values are missed?
# Is it because the missing value was not recorded OR it doesn't exist? You need to read data documentation to learn about data set
#
# If the missing value doesn't exist, like the height of older child for a family without children. You need to keep that value as "NAN".
#
# If the missing value is a missing measurement, you need to try guessing the value. It's called imputation.

# %% [markdown]
# #### 1. Drop missing values (dropna())

# %%
#To remove the rows that have missed values
nfl_v4.dropna()
# Out:
# Empty DataFrame
# ...

# %%
#To remove the columns that have missed values
columns_with_na_dropped = nfl_v4.dropna(axis=1)
print("Number of dropped columns are: " , nfl_v4.shape[1]-columns_with_na_dropped.shape[1])
# Out:
# Number oof dropped columns are:  61

# %% [markdown]
# #### 2. Filling in missing values automatically: with a constant number or with whatever value comes directly after in the same column(fillna())

# %%
nfl_v4_subset = nfl_v4.loc[:,'EPA':'WPA']
nfl_v4_subset.head()
# Out:
#                  EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  \
# Date
# 2009-09-10  2.014474       NaN       NaN     0.485675     0.514325
# 2009-09-10  0.077907 -1.068169  1.146076     0.546433     0.453567
# 2009-09-10 -1.402760       NaN       NaN     0.551088     0.448912
# 2009-09-10 -1.712583  3.318841 -5.031425     0.510793     0.489207
# 2009-09-10  2.097796       NaN       NaN     0.461217     0.538783
#
#             Home_WP_post  Away_WP_post  Win_Prob       WPA
# Date
# 2009-09-10      0.546433      0.453567  0.485675  0.060758
# 2009-09-10      0.551088      0.448912  0.546433  0.004655
# 2009-09-10      0.510793      0.489207  0.551088 -0.040295
# 2009-09-10      0.461217      0.538783  0.510793 -0.049576
# 2009-09-10      0.558929      0.441071  0.461217  0.097712

# %%
nfl_v4_subset.fillna(0).head()
# Out:
#                  EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  \
# Date
# 2009-09-10  2.014474  0.000000  0.000000     0.485675     0.514325
# 2009-09-10  0.077907 -1.068169  1.146076     0.546433     0.453567
# 2009-09-10 -1.402760  0.000000  0.000000     0.551088     0.448912
# 2009-09-10 -1.712583  3.318841 -5.031425     0.510793     0.489207
# 2009-09-10  2.097796  0.000000  0.000000     0.461217     0.538783
#
#             Home_WP_post  Away_WP_post  Win_Prob       WPA
# Date
# 2009-09-10      0.546433      0.453567  0.485675  0.060758
# 2009-09-10      0.551088      0.448912  0.546433  0.004655
# 2009-09-10      0.510793      0.489207  0.551088 -0.040295
# 2009-09-10      0.461217      0.538783  0.510793 -0.049576
# 2009-09-10      0.558929      0.441071  0.461217  0.097712

# %% [markdown]
# Other `methods` that can be used with `fillna`:
# * **bfill :**
#
#   Backward fill: Uses the next valid value below the missing value to fill it.
#   Fills `NaN` with the next known non-null value below it in the same column (if axis=0).
#
# * **ffill:**
#
#   Forward fill: Propagates the last valid value forward to fill gaps.
#   Fills `NaN` with the last known non-null value above it in the same column (if axis=0).

# %%
nfl_v4_subset.fillna(method='bfill',axis=0).fillna(0)
# Out:
#                  EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  \
# Date
# 2009-09-10  2.014474 -1.068169  1.146076     0.485675     0.514325
# 2009-09-10  0.077907 -1.068169  1.146076     0.546433     0.453567
# 2009-09-10 -1.402760  3.318841 -5.031425     0.551088     0.448912
# 2009-09-10 -1.712583  3.318841 -5.031425     0.510793     0.489207
# 2009-09-10  2.097796 -0.343085  0.163935     0.461217     0.538783
# ...              ...       ...       ...          ...          ...
# 2017-12-31  0.000000  0.056697 -0.397515     0.080409     0.919591
# 2017-12-31 -0.340818  0.056697 -0.397515     0.080409     0.919591
# 2017-12-31  0.139913 -2.317201  2.457114     0.050478     0.949522
# 2017-12-31  0.000000  0.000000  0.000000     0.030881     0.969119
# 2017-12-31  0.000000  0.000000  0.000000     0.000000     1.000000
#
#             Home_WP_post  Away_WP_post  Win_Prob       WPA
# Date
# 2009-09-10      0.546433      0.453567  0.485675  0.060758
# ...
